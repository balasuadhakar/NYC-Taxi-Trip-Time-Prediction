# %% [markdown]
# # **Project Name**    - NYC Taxi Trip Time Prediction Regression Project

# %% [markdown]
# ##### **Project Type**    - Regression
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Arumugam Balasuadhakar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# *   The NYC Taxi Trip Duration project is a machine learning regression model that aims to predict the duration of a taxi trip in New York City based on various input features such as the pickup and dropoff locations, the time of day, and the distance of the trip. The goal of the project is to improve the efficiency and convenience of taxi services by providing more accurate estimates of trip duration for both passengers and drivers.
# *   The duration of trip prediction is essential for all travel based business. The current project is based on the machine learning regression model used to predict the taxi trip duration in New York City. The main aim of this project is to provide more precise approximation of trip duration for the customers and drivers.
# *   The past data of taxi trip in NYC have been used for developing the model. The data contained the information such as pickup datetime, dropoff datetime,  Passenger count, pickup longitude, pickup latitude, drop off longitude, drop off latitude, store_and_fwd_flag, and trip duration. The preprocessing was done for the data to handle missing values and transform categorical variables.The additional information such as distance between the location, day of the week  and time have been extracted by applied on future engineering techniques.
# *   The regression algorithms such as linear regression, random forest and XG Boost have been adopted for developing the model. The optimization of the performance of the developed model was done by hyper parameter tuning. The mean absolute error and R-squared are the two  matrices used to evaluate the model. The LightGBM Regression model was performed well compared to other model. The testing of model was done by hold-out test set which is capable to predict high accuracy. It was observed from the result the  model can able to predict the duration of drip with very less average error.
# *   The important features to predict the duration are identified in this project; those are location for pickup and drop, time and the distance. Finally the machine learning regression algorithm has successfully established for predicting the duration of NYC taxi trip.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import datetime as dt

# Importing Statistics Library
import scipy.stats as stats

# Importing Data Visualisation Libraray
import matplotlib.pyplot as plt
import pylab 
import seaborn as sns

# Importing Machine Learning Model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# Importing the rerquired libraries to check the accuracy of the model
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

# Import Warnings filter control
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Google drive mounting
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
file_path= "/content/drive/MyDrive/csv file/NYC Taxi Data.csv"
df = pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.765602                  N            455
# 1         40.731152                  N            663
# 2         40.710087                  N           2124
# 3         40.706718                  N            429
# 4         40.782520                  N            435

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (1458644, 11)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458644 entries, 0 to 1458643
# Data columns (total 11 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id                  1458644 non-null  object
#  1   vendor_id           1458644 non-null  int64
#  2   pickup_datetime     1458644 non-null  object
#  3   dropoff_datetime    1458644 non-null  object
#  4   passenger_count     1458644 non-null  int64
#  5   pickup_longitude    1458644 non-null  float64
#  6   pickup_latitude     1458644 non-null  float64
#  7   dropoff_longitude   1458644 non-null  float64
#  8   dropoff_latitude    1458644 non-null  float64
#  9   store_and_fwd_flag  1458644 non-null  object
#  10  trip_duration       1458644 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 122.4+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().count
# Out:
# <bound method Series.count of 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1458639    False
# 1458640    False
# 1458641    False
# 1458642    False
# 1458643    False
# Length: 1458644, dtype: bool>

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# id                    0
# vendor_id             0
# pickup_datetime       0
# dropoff_datetime      0
# passenger_count       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# store_and_fwd_flag    0
# trip_duration         0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset contains 14,58,644 rows and 11 columns.There is no null values and duplicate values in the dataset. The data types of the pickup_datetime and dropoff_datetime are object type.It need to be converted in to datetime data type.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'store_and_fwd_flag',
#        'trip_duration'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#                id     vendor_id      pickup_datetime     dropoff_datetime  \
# count     1458644  1.458644e+06              1458644              1458644
# unique    1458644           NaN              1380222              1380377
# top     id2875421           NaN  2016-03-04 08:07:34  2016-02-19 19:25:04
# freq            1           NaN                    5                    5
# mean          NaN  1.534950e+00                  NaN                  NaN
# std           NaN  4.987772e-01                  NaN                  NaN
# min           NaN  1.000000e+00                  NaN                  NaN
# 25%           NaN  1.000000e+00                  NaN                  NaN
# 50%           NaN  2.000000e+00                  NaN                  NaN
# 75%           NaN  2.000000e+00                  NaN                  NaN
# max           NaN  2.000000e+00                  NaN                  NaN
#
#         passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count      1.458644e+06      1.458644e+06     1.458644e+06       1.458644e+06
# unique              NaN               NaN              NaN                NaN
# top                 NaN               NaN              NaN                NaN
# freq                NaN               NaN              NaN                NaN
# mean       1.664530e+00     -7.397349e+01     4.075092e+01      -7.397342e+01
# std        1.314242e+00      7.090186e-02     3.288119e-02       7.064327e-02
# min        0.000000e+00     -1.219333e+02     3.435970e+01      -1.219333e+02
# 25%        1.000000e+00     -7.399187e+01     4.073735e+01      -7.399133e+01
# 50%        1.000000e+00     -7.398174e+01     4.075410e+01      -7.397975e+01
# 75%        2.000000e+00     -7.396733e+01     4.076836e+01      -7.396301e+01
# max        9.000000e+00     -6.133553e+01     5.188108e+01      -6.133553e+01
#
#         dropoff_latitude store_and_fwd_flag  trip_duration
# count       1.458644e+06            1458644   1.458644e+06
# unique               NaN                  2            NaN
# top                  NaN                  N            NaN
# freq                 NaN            1450599            NaN
# mean        4.075180e+01                NaN   9.594923e+02
# std         3.589056e-02                NaN   5.237432e+03
# min         3.218114e+01                NaN   1.000000e+00
# 25%         4.073588e+01                NaN   3.970000e+02
# 50%         4.075452e+01                NaN   6.620000e+02
# 75%         4.076981e+01                NaN   1.075000e+03
# max         4.392103e+01                NaN   3.526282e+06

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * id - a unique identifier for each trip
#
# * vendor_id - a code indicating the provider associated with the trip record
#
# * pickup_datetime - date and time when the meter was engaged
#
# * dropoff_datetime - date and time when the meter was disengaged
#
# * passenger_count - the number of passengers in the vehicle (driver entered value)
#
# * pickup_longitude - the longitude where the meter was engaged
#
# * pickup_latitude - the latitude where the meter was engaged
#
# * dropoff_longitude - the longitude where the meter was disengaged
#
# * dropoff_latitude - the latitude where the meter was disengaged
#
# * store_and_fwd_flag - This flag indicates whether the trip record was held in vehicle memory before sending to the vendor because the vehicle did not have a connection to the server - Y=store and forward; N=not a store and forward trip.
#
# * trip_duration - duration of the trip in seconds

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# id                    1458644
# vendor_id                   2
# pickup_datetime       1380222
# dropoff_datetime      1380377
# passenger_count            10
# pickup_longitude        23047
# pickup_latitude         45245
# dropoff_longitude       33821
# dropoff_latitude        62519
# store_and_fwd_flag          2
# trip_duration            7417
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458644 entries, 0 to 1458643
# Data columns (total 11 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id                  1458644 non-null  object
#  1   vendor_id           1458644 non-null  int64
#  2   pickup_datetime     1458644 non-null  object
#  3   dropoff_datetime    1458644 non-null  object
#  4   passenger_count     1458644 non-null  int64
#  5   pickup_longitude    1458644 non-null  float64
#  6   pickup_latitude     1458644 non-null  float64
#  7   dropoff_longitude   1458644 non-null  float64
#  8   dropoff_latitude    1458644 non-null  float64
#  9   store_and_fwd_flag  1458644 non-null  object
#  10  trip_duration       1458644 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 122.4+ MB

# %%
# Converting datetime column from object type to datetime data type
df['pickup_datetime']  = pd.to_datetime(df['pickup_datetime'])
df['dropoff_datetime'] = pd.to_datetime(df['dropoff_datetime'])

# %%
df = df[df.trip_duration <= 3400]

# %%
# Checking the datetime datatype after conversion
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1443457 entries, 0 to 1458643
# Data columns (total 11 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id                  1443457 non-null  object
#  1   vendor_id           1443457 non-null  int64
#  2   pickup_datetime     1443457 non-null  datetime64[ns]
#  3   dropoff_datetime    1443457 non-null  datetime64[ns]
#  4   passenger_count     1443457 non-null  int64
#  5   pickup_longitude    1443457 non-null  float64
#  6   pickup_latitude     1443457 non-null  float64
#  7   dropoff_longitude   1443457 non-null  float64
#  8   dropoff_latitude    1443457 non-null  float64
#  9   store_and_fwd_flag  1443457 non-null  object
#  10  trip_duration       1443457 non-null  int64
# dtypes: datetime64[ns](2), float64(4), int64(3), object(2)
# memory usage: 132.2+ MB

# %%
# Assigning new columns to the dataframe
df['pickup_day_num']   = df.pickup_datetime.dt.weekday
df['dropoff_day_num']   = df.dropoff_datetime.dt.weekday
df['pickup_month']         = df.pickup_datetime.dt.month
df['dropoff_month']         = df.dropoff_datetime.dt.month
df['pickup_hour']   = df.pickup_datetime.dt.hour
df['dropoff_hour']   = df.dropoff_datetime.dt.hour
df['pickup_weekday']       =df['pickup_datetime'].dt.day_name()
df['dropoff_weekday']       =df['dropoff_datetime'].dt.day_name()

# %%
# Function for creating Morning,Afternoon,Evening,Night
def day_period(x):
    if x in range(6,12):
        return 'Morning'
    elif x in range(12,16):
        return 'Afternoon'
    elif x in range(16,22):
        return 'Evening'
    else:
        return 'Night'

# %%
# Creating the columns pickup period and drop period
df['pickup_period'] = df['pickup_hour'].apply(day_period)
df['dropoff_period']=df['dropoff_hour'].apply(day_period)

# %%
# Import haversine formula for calculting distance
# !pip install haversine
from haversine import haversine
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting haversine
#   Downloading haversine-2.8.0-py2.py3-none-any.whl (7.7 kB)
# Installing collected packages: haversine
# Successfully installed haversine-2.8.0

# %%
# Creating function to calculate the distance by latitude and longitute
def calc_distance(taxi_df):
    pickup = (taxi_df['pickup_latitude'], taxi_df['pickup_longitude'])
    drop   = (taxi_df['dropoff_latitude'], taxi_df['dropoff_longitude'])
    return haversine(pickup, drop)

# %%
# Calculate the distance and assigning new column for distance 
df['distance'] = df.apply(lambda x: calc_distance(x), axis = 1)

# %%
# Calculating the speed of trip and assigning new column
df['speed'] = (df.distance/(df.trip_duration/3600))

# %%
# Checking all the new columns
df.head(2)
# Out:
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1  id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
#
#    dropoff_latitude store_and_fwd_flag  ...  pickup_month  dropoff_month  \
# 0         40.765602                  N  ...             3              3
# 1         40.731152                  N  ...             6              6
#
#    pickup_hour  dropoff_hour  pickup_weekday  dropoff_weekday  pickup_period  \
# 0           17            17          Monday           Monday        Evening
# 1            0             0          Sunday           Sunday          Night
#
#   dropoff_period  distance      speed
# 0        Evening  1.498523  11.856445
# 1          Night  1.805510   9.803672
#
# [2 rows x 23 columns]

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The following manipulations were done in the datawrangling process
#
#
# *   The pickup and drop datetime columns were converted to datetime data type from object type.
# *   Assigning new columns to the dataframe for weekday number, month,hour and weekday,period for both pickup and dropoff.
# *   Distance was calculated for each trip and added as a new column.
# *   Speed of the trip was calculated and added as a new column.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 Vsualization code
# Passanger count of the trips
df.passenger_count.value_counts()
# Out:
# 1    1023736
# 2     207556
# 5      77174
# 3      59183
# 6      47755
# 4      27989
# 0         59
# 7          3
# 9          1
# 8          1
# Name: passenger_count, dtype: int64

# %%
# Visulaization of passanger count
sns.set(rc={'figure.figsize':(10,5)});
sns.countplot(x='passenger_count',data=df)
plt.title('Number of passangers traveled in trips');
plt.xlabel('Number of passangers')
plt.ylabel('Number of trips')
# Out:
# Text(0, 0.5, 'Number of trips')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Tofind the number of passangers traveled in each trips

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the trips are with single passanger.Seven passangers with 3 trips and without passanger 60 trip.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Number passangers traveled in most of the trips are identified.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 Visualization code
# Visualization of trip duration
plt.figure(figsize=[12,6])
labels=['less then 1min','within 15 mins','within 30 mins','within hour','within day','within two days','more then two day']
df.groupby(pd.cut(df['trip_duration'],bins=[0,60,900,1800,3600,86400,86400*2,10000000],labels=labels))['trip_duration'].count().plot(kind='bar',fontsize=10)
plt.title("Duration of travel for trips")
plt.ylabel("Number of trips")
plt.xlabel("Duration of trip")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the duration of trips

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some trips are less than one minutes, some trips are within the day.Most of the trips are within 15 minutes and within 30 minutes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By identifying trip duration company can plan for better utilization of vehicles.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

df['vendor_id'].value_counts().plot(kind='pie',title="Vendors",autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Vendors'}, ylabel='vendor_id'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the percentage of trips completed by each vendor.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Both the vendors completed trips almost equal percentage. Vendor 2 slightly more compared to vendore 1

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# based on the trips of vendors copany can identify the performance of each vendors

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Visualization of distance traveled
ax = df['distance'].hist(bins=50, figsize=(20,6),color='pink')
ax.set_yscale('log')
ax.set_xlabel("Distance Traveled (km)")
ax.set_ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the distance traveled by the vehicles.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Visualization of Store and Forward Flag Y & N
plt.figure(figsize = (12,10))
total = float(len(df))
ax=sns.countplot(x='store_and_fwd_flag',data=df)
plt.ylabel('Count')
plt.xlabel('store_and_fwd_flag')
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='right')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check whether the trip details stored in the vehicle memory

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The trip details stored in vehicle memory is 0.6% only

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Company can take necessary steps to improve the detaile storing in vehicle memory

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Visualization of speed
plt.figure(figsize = (10,5))
sns.distplot(df['speed'])
plt.xlabel('Speed (km/hr)')
plt.show()

# %%
# Maximum speed of the vehicle
df.speed.max()
# Out:
# 9274.849542192556

# %% [markdown]
# Some place speed are 200 to 9274. This may be due to following reasons
# *   Due to some technical issue of software
# *   Some trip passanger or driver cancelled the trip due to some reasons.
#
# So inorder to havethe consistance data we take speed value less than or equalto 100 km/h

# %%
# visulaization of traveled speed of vehicles less than or equal 100 km/h
df[df.speed<=100].speed.groupby(pd.cut(df.speed, np.arange(0,110,10))).count().plot(kind = 'barh',figsize = (20,6))
plt.xlabel('Number of trips')
plt.ylabel('Speed (kmph)')
plt.title('Traveled speed of vehicles')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the speed of vehicles in most of the trips.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the trips are between 10 to 20 km/h.Very few trips are 50 to 60km/h

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The company can identify the very low speed and high speed and the can find the reason for low and high speed.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
figure,(ax3,ax4)=plt.subplots(ncols=2,figsize=(20,5))
ax3.set_title('Pickup Time of Day (24hr format)')
ax=sns.countplot(x="pickup_hour",data=df,ax=ax3)
ax4.set_title('Dropoff Time of Day (24hr format)')
ax=sns.countplot(x="dropoff_hour",data=df,ax=ax4)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the busiest hours in pickup and dropoff.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# More busiest hours in pickup and dropoff is between 6pm to 7pm.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# More demand period for vehicles have been identified and company may provide extra vehicle during that time.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Visualization of pickup and dropoff in monthwise
figure,(ax1,ax2)=plt.subplots(ncols=2,figsize=(20,5))
ax1.set_title('Pickup Months (Jan=1 to June=6)')
ax=sns.countplot(x="pickup_month",data=df,ax=ax1)
ax2.set_title('Dropoff Months (Jan=1 to June=6)')
ax=sns.countplot(x="dropoff_month",data=df,ax=ax2)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check the monthwise details of pickup and dropoff

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# March, April and May months more demand for the vehicles compared to other months.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Which are months have more demands have been idendified.The organisation may provide extra vehicles during that months.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Visualization of passenger count Vs duration of trip
figure,(ax3,ax4)=plt.subplots(ncols=2,figsize=(20,5))
ax3.set_title('Pickup Periods')
ax=sns.countplot(x="pickup_period",data=df,ax=ax3)
ax4.set_title('Dropoff Periods')
ax=sns.countplot(x="dropoff_period",data=df,ax=ax4)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find which period of the day pickup and dropoff are more.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Pickup and dropoff are more in evening period and morning period.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Evening and morning periods pickup and dropoff are more the company can make ready more vehicles during that periods.Afternoon period the demand of vehicle is less, so the company can reduce the number of vehicles in afternoon.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
figure,(ax1,ax2)=plt.subplots(ncols=2,figsize=(18,5))
ax1.set_title('Pickup week Days')
ax=sns.countplot(x="pickup_weekday",data=df,ax=ax1)
ax2.set_title('Dropoff week Days')
ax=sns.countplot(x="dropoff_weekday",data=df,ax=ax2)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find which day of the week vehicle demand are more.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Friday and Saturday the vehicle usage is more.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Friday and Saturday the vehicle usage is more so extra vehicles need to be provided that two days.During monday very less usage of vehicles they can improve the usage by giving some discounts.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Visualization of pickup location
lat=df.sample(n=10000, random_state=42)['pickup_latitude'].tolist()
lon=df.sample(n=10000, random_state=42)['pickup_longitude'].tolist()

# Importing plotly express library
import plotly.express as px

# Create a DataFrame with columns 'lat' and 'lon'
data_ = pd.DataFrame({
    'lat': lat,
    'lon': lon
})

# Create a density map
fig = px.density_mapbox(data_, lat='lat', lon='lon', radius=10, zoom=9,
                        mapbox_style="carto-positron", opacity=0.8)
fig.update_layout(title='Pick Up Locations', width=900, height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="0ce696d7-6cbf-4e25-b439-ced4ae550447" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ce696d7-6cbf-4e25-b439-ced4ae550447")) {                    Plotly.newPlot(                        "0ce696d7-6cbf-4e25-b439-ced4ae550447",                        [{"coloraxis":"coloraxis","hovertemplate":"lat=%{lat}<br>lon=%{lon}<extra></extra>","lat":[40.78196334838867,40.72126388549805,40.75308609008789,40.777050018310554,40.718875885009766,40.767459869384766,40.74427032470703,40.76678085327149,40.76688766479492,40.74023818969727,40.78325653076172,40.7793197631836,40.721412658691406,40.718608856201165,40.760520935058594,40.749122619628906,40.77524566650391,40.739253997802734,40.773658752441406,40.75543212890625,40.71824264526367,40.73859024047852,40.752479553222656,40.757450103759766,40.764663696289055,40.742305755615234,40.761810302734375,40.7818603515625,40.75886917114258,40.735233306884766,40.76422119140625,40.839458465576165,40.70637130737305,40.7513084411621,40.72751998901367,40.74720001220703,40.70494079589844,40.756309509277344,40.7581901550293,40.746829986572266,40.73788070678711,40.765491485595696,40.75044631958008,40.75112915039063,40.72907638549805,40.74070358276367,40.72263717651367,40.711475372314446,40.74782180786133,40.78512573242188,40.785350799560554,40.73775100708008,40.7342185974121,40.72432327270508,40.73780059814453,40.75727081298828,40.749858856201165,40.79226303100586,40.73703002929688,40.779205322265625,40.76040267944336,40.7596092224121,40.73801040649414,40.77907943725586,40.74850845336913,40.7529296875,40.78260040283203,40.7580451965332,40.7569694519043,40.732734680175774,40.746620178222656,40.733783721923835,40.765655517578125,40.724830627441406,40.7579345703125,40.7583236694336,40.754985809326165,40.82329940795898,40.73500061035156,40.77177047729492,40.76206207275391,40.73855972290039,40.703250885009766,40.74747467041016,40.76617813110352,40.73127365112305,40.68111038208008,40.73965835571289,40.73226165771485,40.7729606628418,40.78274917602539,40.7045783996582,40.79951858520508,40.75580596923828,40.72521209716797,40.76482009887695,40.766796112060554,40.76784896850586,40.727588653564446,40.74069213867188,40.7651481628418,40.751312255859375,40.74299621582031,40.77409362792969,40.77952575683594,40.735889434814446,40.733413696289055,40.75469970703125,40.73480987548828,40.72969818115234,40.7506103515625,40.782745361328125,40.759708404541016,40.78799819946289,40.72745132446289,40.77455520629882,40.757755279541016,40.80376815795898,40.75556182861328,40.78632354736328,40.73455429077149,40.73060989379882,40.703800201416016,40.8084716796875,40.760040283203125,40.74288177490234,40.70956039428711,40.78394317626953,40.64471435546875,40.76360702514648,40.77853012084961,40.749881744384766,40.756927490234375,40.740039825439446,40.77228164672852,40.76753616333008,40.771034240722656,40.744941711425774,40.74602127075195,40.73307037353516,40.7612190246582,40.73489761352539,40.72669982910156,40.74383163452149,40.76918029785156,40.71128845214844,40.74153518676758,40.72441101074219,40.72067260742188,40.74810791015625,40.76974868774414,40.71225357055664,40.74370956420898,40.782901763916016,40.7522087097168,40.748077392578125,40.73797225952149,40.773773193359375,40.761478424072266,40.7603645324707,40.72671890258789,40.78410339355469,40.73308563232422,40.74753189086913,40.76430892944336,40.756591796875,40.79541778564453,40.75691986083984,40.78116607666016,40.77505111694336,40.740249633789055,40.74431610107422,40.748008728027344,40.7843017578125,40.72663879394531,40.74383163452149,40.768009185791016,40.79783248901367,40.720897674560554,40.70547866821289,40.73237228393555,40.76339721679688,40.812278747558594,40.77131652832031,40.729583740234375,4 ...

# %%
# Visualization of dropoff location
lat=df.sample(n=10000, random_state=42)['dropoff_latitude'].tolist()
lon=df.sample(n=10000, random_state=42)['dropoff_longitude'].tolist()

# Importing plotly express library
import plotly.express as px

# Create a DataFrame with columns 'lat' and 'lon'
data_ = pd.DataFrame({
    'lat': lat,
    'lon': lon
})

# Create a density map
fig = px.density_mapbox(data_, lat='lat', lon='lon', radius=10, zoom=9,
                        mapbox_style="carto-positron", opacity=0.8)
fig.update_layout(title='Dropoff Locations', width=900, height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="58d455fb-4a67-45b9-a043-54bfc1401a43" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58d455fb-4a67-45b9-a043-54bfc1401a43")) {                    Plotly.newPlot(                        "58d455fb-4a67-45b9-a043-54bfc1401a43",                        [{"coloraxis":"coloraxis","hovertemplate":"lat=%{lat}<br>lon=%{lon}<extra></extra>","lat":[40.76387786865234,40.76258850097656,40.74435043334961,40.76129150390625,40.686485290527344,40.75762939453125,40.76230239868164,40.701763153076165,40.77658462524414,40.75920104980469,40.77254104614258,40.757671356201165,40.77424621582031,40.72177505493164,40.76827621459961,40.75992202758789,40.78464889526367,40.72136688232422,40.82952880859375,40.750534057617195,40.72898483276367,40.717109680175774,40.7607307434082,40.76723098754882,40.75894927978516,40.748729705810554,40.775089263916016,40.78823852539063,40.79841995239258,40.710845947265625,40.7581787109375,40.8596305847168,40.713645935058594,40.73424911499024,40.727169036865234,40.73673248291016,40.715126037597656,40.73854064941406,40.70930099487305,40.75373840332031,40.750450134277344,40.760101318359375,40.77507019042969,40.74404144287109,40.74150848388672,40.75987243652344,40.74835586547852,40.756629943847656,40.73819351196289,40.779651641845696,40.7278709411621,40.762821197509766,40.74432373046875,40.72821807861328,40.74861907958984,40.720260620117195,40.76416015625,40.788887023925774,40.782901763916016,40.744186401367195,40.74626159667969,40.80069351196289,40.751026153564446,40.76654052734375,40.763431549072266,40.73994827270508,40.755218505859375,40.75794982910156,40.7247428894043,40.73854446411133,40.7426986694336,40.754070281982415,40.781246185302734,40.7420310974121,40.77736282348633,40.80474472045898,40.760208129882805,40.8081283569336,40.76081085205078,40.765331268310554,40.79625701904297,40.74031066894531,40.6089973449707,40.76268768310546,40.76984024047852,40.72488784790039,40.68503952026367,40.75231170654297,40.76163482666016,40.6450309753418,40.78459167480469,40.75054168701172,40.82485580444336,40.75698852539063,40.768287658691406,40.76482009887695,40.77681350708008,40.78889846801758,40.76129913330078,40.762893676757805,40.7501220703125,40.75463104248047,40.73469924926758,40.75020599365234,40.80475616455078,40.74140167236328,40.68721771240234,40.74227142333984,40.74396133422852,40.718658447265625,40.75387954711913,40.77172088623047,40.76401519775391,40.76653671264648,40.78062438964844,40.759090423583984,40.75995635986328,40.77117919921875,40.7589111328125,40.75023651123047,40.7265739440918,40.73836898803711,40.704498291015625,40.75008392333984,40.718544006347656,40.749359130859375,40.76461791992188,40.79080581665039,40.74393844604492,40.72862243652344,40.74075698852539,40.73434066772461,40.758148193359375,40.761009216308594,40.7778205871582,40.75038909912109,40.74566268920898,40.76435089111328,40.75675964355469,40.775020599365234,40.75408172607422,40.77289581298828,40.72833251953125,40.73648834228516,40.68569946289063,40.706687927246094,40.742950439453125,40.74038314819336,40.750930786132805,40.77170181274414,40.75764846801758,40.7201042175293,40.75509643554688,40.741485595703125,40.750385284423835,40.73355865478516,40.72886657714844,40.7701416015625,40.72213745117188,40.7934684753418,40.73915100097656,40.74666213989258,40.76911544799805,40.730518341064446,40.7978744506836,40.72321701049805,40.77626800537109,40.738868713378906,40.78555679321289,40.77874374389648,40.71786117553711,40.756790161132805,40.76030731201172,40.77629470825195,40.75218963623047,40.75209045410156,40.78044891357422,40.80075073242188,40.75131988525391,40.73590850830078,40.7692985534668,40.77885055541992,40.79539108276367,40.77643585205078,40.73680877685546,40.77315 ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find which location pick up and drop are more

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the pick up and dropoff locations have been identified.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In most demand pickup locations company they can keep more vehicles.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Visualization of number of trips in each time for both vendor
sns.countplot(x=df['pickup_datetime'].dt.hour, hue=df['vendor_id'] )
plt.xlabel('Pick Up Time')
plt.ylabel('No. of Trips')
plt.title('Trips Over a Day')
plt.show()
# Out:
# <Axes: xlabel='pickup_datetime', ylabel='count'>
# Text(0.5, 0, 'Pick Up Time')
# Text(0, 0.5, 'No. of Trips')
# Text(0.5, 1.0, 'Trips Over a Day')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the number of trips for each vendors time wise.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# During 7pm to 8pm the trips are more for both vendors.Vendore 2 is more compared to vendore 1 during that period.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# During peak hour vendore 1 trips are less it need to be rectified by finding the reason.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Visualization of store and fwd flag with distance
plt.figure(figsize = (10,5))
sns.barplot(y='trip_duration',x='vendor_id',data=df)
plt.xlabel('Vendor ID')
plt.ylabel('Trip Duration')
plt.show()
# Out:
# <Axes: xlabel='vendor_id', ylabel='trip_duration'>
# Text(0.5, 0, 'Vendor ID')
# Text(0, 0.5, 'Trip Duration')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To compare the duration of trips for both vendors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Vendore 2 has the more duration of trips.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Vendore 2 vehicles traveling more duration so the vehicles need to be in proper maintenance.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Visualization of correlation between all variables
plt.figure(figsize=(20,10))
corr=df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the correlation between all the variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# pickup hour and drop hour highly correlated.trip duration nd distance highly correlated.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The correlation values between the variables shows their relations.The company can identify how value changing based on the variables.

# %%
df.head(1)
# Out:
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937          -73.96463
#
#    dropoff_latitude store_and_fwd_flag  ...  pickup_month  dropoff_month  \
# 0         40.765602                  N  ...             3              3
#
#    pickup_hour  dropoff_hour  pickup_weekday  dropoff_weekday  pickup_period  \
# 0           17            17          Monday           Monday        Evening
#
#   dropoff_period  distance      speed
# 0        Evening  1.498523  11.856445
#
# [1 rows x 23 columns]

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Visualization of Trip Duration v/s Passanger count
sns.boxplot(x=df['passenger_count'],y=df['trip_duration'])
plt.title('Trip Duration v/s Passanger count')
# Out:
# <Axes: xlabel='passenger_count', ylabel='trip_duration'>
# Text(0.5, 1.0, 'Trip Duration v/s Passanger count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check the passanger count and trip duration relation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# During 4 passanger traveling the trip duration are more.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The trip duration is more during 4 passanger travel.The company can instruct the drivers while travel with 4 passanger keep excess fuel.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
